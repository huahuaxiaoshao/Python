# %%
import sys
from collections import defaultdict
from itertools import combinations
import numpy as np
import random
import csv
import pdb

# %%
from pyspark import SparkContext
from recsys import evaluate

# %% [markdown]
# # 加载数据

# %%
lines = sc.textFile('file:///home/hadoop/workspaces/spark_knn_recommender/ratings.txt')

# %%
def parseVector(line):
    line = line.split('|')
    return line[0],(line[1],float(line[2]))

# %%
def sampleInteractions(user_id,items_with_rating,n):
    '''
    For users with # interactions > n, replace their interaction history
    with a sample of n items_with_rating
    '''
    if len(items_with_rating) > n:
        return user_id,random.sample(list(items_with_rating),n)
    else:
        return user_id,items_with_rating

# %%
''' 
Obtain the sparse user-item matrix:
    user_id -> [(item_id_1, rating_1),
               [(item_id_2, rating_2),
                ...]
'''
user_item_pairs = lines.map(parseVector)\
                    .groupByKey()\
                    .map(lambda p : sampleInteractions(p[0],p[1],500)).cache()

# %%
user_item_pairs.count()
# Out:
# 943

# %%
def findItemPairs(user_id,items_with_rating):
    '''
    For each user, find all item-item pairs combos. (i.e. items with the same user) 
    '''
    for item1,item2 in combinations(items_with_rating,2):
        return (item1[0],item2[0]),(item1[1],item2[1])

# %%
'''
Get all item-item pair combos:
    (item1,item2) ->    [(item1_rating,item2_rating),
                         (item1_rating,item2_rating),
                         ...]
'''
# Out:
# '\nGet all item-item pair combos:\n    (item1,item2) ->    [(item1_rating,item2_rating),\n                         (item1_rating,item2_rating),\n                         ...]\n'

# %%
pairwise_items = user_item_pairs.filter(lambda p : len(p[1]) > 1)\
                                .map(lambda p : findItemPairs(p[0],p[1])).groupByKey()

# %%
pairwise_items.count()
# Out:
# 938

# %%
def cosine(dot_product,rating_norm_squared,rating2_norm_squared):
    '''
    The cosine between two vectors A, B
       dotProduct(A, B) / (norm(A) * norm(B))
    '''
    numerator = dot_product
    denominator = rating_norm_squared * rating2_norm_squared
    return (numerator / (float(denominator))) if denominator else 0.0

# %%
def calcSim(item_pair,rating_pairs):
    ''' 
    For each item-item pair, return the specified similarity measure,
    along with co_raters_count
    '''
    sum_xx, sum_xy, sum_yy, n = (0.0, 0.0, 0.0, 0)
#     rating_pairs = list(rating_pairs)
    for rating_pair in rating_pairs:
        sum_xx += np.float(rating_pair[0]) * np.float(rating_pair[0])
        sum_yy += np.float(rating_pair[1]) * np.float(rating_pair[1])
        sum_xy += np.float(rating_pair[0]) * np.float(rating_pair[1])
        n += 1
        
    cos_sim = cosine(sum_xy,np.sqrt(sum_xx),np.sqrt(sum_yy))
    return item_pair,(cos_sim)

# %%
def keyOnFirstItem(item_pair,item_sim_data):
    '''
    For each item-item pair, make the first item's id the key
    '''
    (item1_id,item2_id) = item_pair
    return item1_id,(item2_id,item_sim_data)

# %%
def nearestNeighbors(item_id,items_and_sims,n):
    '''
    Sort the predictions list by similarity and select the top-N neighbors
    '''
    items_and_sims.sort(key = lambda x : x[1],reverse = True)
    if len(items_and_sims) < n:
        n = len(items_and_sims)
    return item_id,items_and_sims[:n]

# %%
'''
Calculate the cosine similarity for each item pair and select the top-N nearest neighbors:
    (item1,item2) ->    (similarity,co_raters_count)
 '''
item_sims = pairwise_items.map(lambda p: calcSim(p[0],p[1]))\
                          .map(lambda p: keyOnFirstItem(p[0],p[1]))\
                          .groupByKey()\
                          .map(lambda p : (p[0], list(p[1])))\
                          .map(lambda p: nearestNeighbors(p[0],p[1],50))

# %%
item_sims.count()

# %%
item_sims.take(1)
# Out:
# [('Die Hard (1988)',
#   [('Star Trek III: The Search for Spock (1984)', 1.0),
#    ('Pump Up the Volume (1990)', 1.0),
#    ('Flirting With Disaster (1996)', 1.0),
#    ('Pulp Fiction (1994)', 1.0),
#    ("McHale's Navy (1997)", 1.0)])]

# %%
'''
Preprocess the item similarity matrix into a dictionary and store it as a broadcast variable:
'''
item_sim_dict = {}
for (item,data) in item_sims.collect(): 
    item_sim_dict[item] = data
isb = sc.broadcast(item_sim_dict)

# %%
item_sim_dict
# Out:
# {'12 Angry Men (1957)': [('Stag (1997)', 1.0), ('Game, The (1997)', 1.0)],
#  '187 (1997)': [('English Patient, The (1996)', 1.0)],
#  '2001: A Space Odyssey (1968)': [('Get on the Bus (1996)', 1.0),
#   ('Victor/Victoria (1982)', 1.0),
#   ('Liar Liar (1997)', 1.0),
#   ('Twelve Monkeys (1995)', 1.0)],
#  '8 1/2 (1963)': [("Schindler's List (1993)", 1.0)],
#  'Abyss, The (1989)': [('Some Folks Call It a Sling Blade (1993)', 1.0),
#   ('Body Snatchers (1993)', 1.0),
#   ('Liar Liar (1997)', 1.0)],
#  'Ace Ventura: Pet Detective (1994)': [('Clerks (1994)', 1.0)],
#  'Addams Family Values (1993)': [('Great White Hype, The (1996)', 1.0)],
#  'Adventures of Pinocchio, The (1996)': [('One Fine Day (1996)', 1.0)],
#  'Adventures of Priscilla, Queen of the Desert, The (1994)': [('Crimson Tide (1995)',
#    1.0),
#   ('High Noon (1952)', 1.0),
#   ('Quiet Man, The (1952)', 1.0)],
#  'African Queen, The (1951)': [('Quiz Show (1994)', 1.0)],
#  'Afterglow (1997)': [('Edge, The (1997)', 1.0)],
#  'Age of Innocence, The (1993)': [('My Left Foot (1989)', 1.0)],
#  'Air Force One (1997)': [('Midnight in the Garden of Good and Evil (1997)',
#    1.0),
#   ('Basquiat (1996)', 1.0),
#   ('Rainmaker, The (1997)', 1.0),
#   ('Apt Pupil (1998)', 1.0),
#   ('Jurassic Park (1993)', 1.0),
#   ('Fallen (1998)', 1.0),
#   ("Devil's Advocate, The (1997)", 1.0),
#   ('Picture Perfect (1997)', 1.0),
#   ('Jerry Maguire (1996)', 1.0)],
#  'Akira (1988)': [('Serial Mom (1994)', 1.0)],
#  'Aladdin (1992)': [('Conspiracy Theory (1997)', 1.0),
#   ('Homeward Bound: The Incredible Journey (1993)', 1.0),
#   ('Milk Money (1994)', 1.0)],
#  'Aladdin and the King of Thieves (1996)': [('Congo (1995)', 1.0)],
#  'Alien (1979)': [('Wizard of Oz, The (1939)', 1.0)],
#  'Alien: Resurrection (1997)': [('Bean (1997)', 1.0)],
#  'Aliens (1986)': [('Mary Poppins (1964)', 1.0),
#   ('Graduate, The (1967)', 1.0)],
#  'All About Eve (1950)': [('Gay Divorcee, The (1934)', 1.0)],
#  'Amadeus (1984)': [('Daytrippers, The (1996)', 1.0),
#   ('Full Monty, The (1997)', 1.0)],
#  'American President, The (1995)': [('Sound of Music, The (1965)', 1.0),
#   ('Fargo (1996)', 1.0)],
#  'Amistad (1997)': [('L.A. Confidential (1997)', 1.0)],
#  'Anastasia (1997)': [('Evita (1996)', 1.0), ("Marvin's Room (1996)", 1.0)],
#  'Angels and Insects (1995)': [('Private Parts (1997)', 1.0)],
#  'Anna Karenina (1997)': [("Cats Don't Dance (1997)", 1.0),
#   ('Great Expectations (1998)', 1.0)],
#  'Annie Hall (1977)': [('Amadeus (1984)', 1.0),
#   ('Star Trek VI: The Undiscovered Country (1991)', 1.0),
#   ('Absolute Power (1997)', 1.0)],
#  'Apocalypse Now (1979)': [('Boot, Das (1981)', 1.0)],
#  'Apollo 13 (1995)': [('Ben-Hur (1959)', 1.0),
#   ('Raiders of the Lost Ark (1981)', 1.0),
#   ('Beauty and the Beast (1991)', 1.0),
#   ('Last Dance (1996)', 1.0),
#   ('Babe (1995)', 1.0),
#   ('Silence of the Lambs, The (1991)', 1.0),
#   ('Feeling Minnesota (1996)', 1.0)],
#  'Apostle, The (1997)': [('Wedding Singer, The (1998)', 1.0),
#   ('Blues Brothers 2000 (1998)', 1.0)],
#  'Apt Pupil (1998)': [('Emma (1996)', 1.0),
#   ('Seven (Se7en) (1995)', 1.0),
#   ('Spice World (1997)', 1.0)],
#  'Arrival, The (1996)': [('Twelve Monkeys (1995)', 1.0)],
#  'Assignment, The (1997)': [('Forrest Gump (1994)', 1.0)],
#  'Ayn Rand: A Sense of Life (1997)': [('Wonderland (1997)', 1.0)],
#  'Babe (1995)': [('American in Paris, An (1951)', 1.0),
#   ('Silence of the Lambs, The (1991)', 1.0)],
#  'Back to the Future (1985)': [('Lassie (1994)', 1.0),
#   ('Fargo (1996)', 1.0),
#   ('Young Frankenstein (1974)', 1.0)],
#  'Basic Instinct (1992)': [('Nightmare on Elm Street, A (1984)', 1.0)],
#  'Batman Forever (1995)': [("Devil's Own, The (1997)", 1.0)],
#  'Batman Returns (1992)': [('Cool Runnings (1993)', 1.0)],
#  'Bean (1997)': [('Die Hard: With a Vengeance (1995)', 1.0),
#   ('Kiss the Girls (1997)', 1.0)],
#  'Beautiful Girls (1996)': [('Seven Years in Tibet (1997)', 1.0),
#   ("Marvin's Room (1996)", 1.0)],
#  'Beautiful Thing (1996)': [("Preacher's Wife, The (1996)", 1.0)],
#  'Beauty and the Beast (1991)': [('Persuasion (1995)', 1.0),
#   ('Return of the Jedi (1983)', 1.0)],
#  'Bed of Roses (1996)': [('Grand Day Out, A (1992)', 1.0),
#   ('Evita (1996)', 1.0)],
#  'Bedknobs and Broomsticks (1971)': [('Shawshank Redemption, The (1994)',
#    1.0)],
#  'Before Sunrise (1995)': [('Aliens (1986)', 1.0)],
#  'Ben-Hur (1959)': [('Piano, The (1993)', 1.0)],
#  'Benny & Joon (1993)': [('Corrina, Corrina (1994)', 1.0)],
#  'Big Blue, The (Grand bleu, Le) (1988)': [('Fifth Element, The (1997)', 1.0)],
#  'Big Night (1996)': [('Total Eclipse (1995)', 1.0)],
#  'Bio-Dome (1996)': [('Apt Pupil (1998)', 1.0)],
#  'Birdcage, The (1996)': [('Mystery Science Theater 3000: The Movie (1996)',
#    1.0),
#   ("Devil's Advocate, The (1997)", 1.0),
#   ('Courage Under Fire (1996)', 1.0),
#   ('Die xue shuang xiong (Killer, The) (1989)', 1.0),
#   ('Cool Hand Luke (1967)', 1.0),
#   ('Dead Man Walking (1995)', 1.0)],
#  'Birds, The (1963)': [('Wedding Singer, The (1998)', 1.0),
#   ('Pulp Fiction (1994)', 1.0),
#   ('Brothers McMullen, The (1995)', 1.0)],
#  'Blade Runner (1982)': [('This Is Spinal Tap (1984)', 1.0),
#   ('Raiders of the Lost Ark (1981)', 1.0),
#   ('Little Women (1994)', 1.0),
#   ('Leaving Las Vegas (1995)', 1.0),
#   ('Citizen Kane (1941)', 1.0)],
#  'Blob, The (1958)': [('Alien (1979)', 1.0)],
#  'Blues Brothers 2000 (1998)': [('Chasing Amy (1997)', 1.0),
#   ('Titanic (1997)', 1.0)],
#  'Blues Brothers, The (1980)': [('Trigger Effect, The (1996)', 1.0),
#   ('Beyond Rangoon (1995)', 1.0),
#   ('Jaws 2 (1978)', 1.0)],
#  'Bonnie and Clyde (1967)': [('Godfather, The (1972)', 1.0)],
#  'Boogie Nights (1997)': [("Things to Do in Denver when You're Dead (1995)",
#    1.0),
#   ("She's So Lovely (1997)", 1.0),
#   ('Peacemaker, The (1997)', 1.0)],
#  'Boot, Das (1981)': [('Absolute Power (1997)', 1.0),
#   ('Raiders of the Lost Ark (1981)', 1.0)],
#  'Booty Call (1997)': [('Chasing Amy (1997)', 1.0),
#   ('Jungle2Jungle (1997)', 1.0),
#   ('Starship Troopers (1997)', 1.0)],
#  'Brady Bunch Movie, The (1995)': [('True Lies (1994)', 1.0),
#   ('Seven (Se7en) (1995)', 1.0)],
#  'Braindead (1992)': [('Omen, The (1976)', 1.0)],
#  'Braveheart (1995)': [('Blues Brothers, The (1980)', 1.0),
#   ('Dumbo (1941)', 1.0),
#   ('Batman (1989)', 1.0)],
#  'Brazil (1985)': [('To Die For (1995)', 1.0)],
#  'Bread and Chocolate (Pane e cioccolata) (1973)': [('12 Angry Men (1957)',
#    1.0)],
#  'Breaking the Waves (1996)': [('Chasing Amy (1997)', 1.0)],
#  'Bridge on the River Kwai, The (1957)': [('Amadeus (1984)', 1.0)],
#  'Broken Arrow (1996)': [('Sword in the Stone, The (1963)', 1.0),
#   ('Time to Kill, A (1996)', 1.0),
#   ('Rock, The (1996)', 1.0),
#   ('Lone Star (1996)', 1.0)],
#  'Bronx Tale, A (1993)': [('SubUrbia (1997)', 1.0)],
#  'Brothers McMullen, The (1995)': [('Little Women (1994)', 1.0),
#   ('Maltese Falcon, The (1941)', 1.0)],
#  'Bullets Over Broadway (1994)': [('Twelve Monkeys (1995)', 1.0)],
#  'Cape Fear (1962)': [('Arsenic and Old Lace (1944)', 1.0),
#   ('Fugitive, The (1993)', 1.0)],
#  'Cape Fear (1991)': [('Fish Called Wanda, A (1988)', 1.0),
#   ('Sting, The (1973)', 1.0)],
#  'Casablanca (1942)': [('Madness of King George, The (1994)', 1.0),
#   ('Fargo (1996)', 1.0)],
#  'Casper (1995)': [('Mulholland Falls (1996)', 1.0),
#   ('Jerry Maguire (1996)', 1.0)],
#  'Celluloid Closet, The (1995)': [('Nightmare on Elm Street, A (1984)', 1.0)],
#  'Chasing Amy (1997)': [('Soul Food (1997)', 1.0),
#   ("Ulee's Gold (1997)", 1.0),
#   ('Mulholland Falls (1996)', 1.0),
#   ('Contact (1997)', 1.0)],
#  'Christmas Carol, A (1938)': [('Man Without a Face, The (1993)', 1.0)],
#  'Cinderella (1950)': [('Lone Star (1996)', 1.0)],
#  'Cinema Paradiso (1988)': [('Liar Liar (1997)', 1.0)],
#  'Circle of Friends (1995)': [('Truth About Cats & Dogs, The (1996)', 1.0)],
#  'Citizen Kane (1941)': [('Heat (1995)', 1.0)],
#  'Client, The (1994)': [('Star Trek: First Contact (1996)', 1.0)],
#  'Clockwork Orange, A (1971)': [('Blade Runner (1982)', 1.0)],
#  'Close Shave, A (1995)': [('Toy Story (1995)', 1.0)],
#  'Cold Comfort Farm (1995)': [('Four Weddings and a Funeral (1994)', 1.0),
#   ('Rumble in the Bronx (1995)', 1.0),
#   ('Brassed Off (1996)', 1.0)],
#  'Con Air (1997)': [('Kiss the Girls (1997)', 1.0)],
#  'Conan the Barbarian (1981)': [('Terminator, The (1984)', 1.0)],
#  'Conspiracy Theory (1997)': [('In & Out (1997)', 1.0),
#   ('Deconstructing Harry (1997)', 1.0),
#   ('Air Force One (1997)', 1.0),
#   ('Great White Hype, The (1996)', 1.0),
#   ('Wag the Dog (1997)', 1.0),
#   ('Lost Highway (1997)', 1.0),
#   ('As Good As It Gets (1997)', 1.0),
#   ('Jackal, The (1997)', 1.0)],
#  'Contact (1997)': [('Mystery Science Theater 3000: The Movie (1996)', 1.0),
#   ('Chain Reaction (1996)', 1.0),
#   ('English Patient, The (1996)', 1.0),
#   ("Schindler's List (1993)", 1.0),
#   ("Ulee's Gold (1997)", 1.0)],
#  'Cool Runnings (1993)': [('American President, The (1995)', 1.0)],
#  'Cop Land (1997)': [('Toy Story (1995)', 1.0),
#   ("It's a Wonderful Life (1946)", 1.0)],
#  'Copycat (1995)': [('Volcano (1997)', 1.0),
#   ('Executive Decision (1996)', 1.0)],
#  'Cosi (1996)': [('Jingle All the Way (1996)', 1.0)],
#  'Courage Under Fire (1996)': [('Star Trek III: The Search for Spock (1984)',
#    1.0),
#   ('Bed of Roses (1996)', 1.0)],
#  'Craft, The (1996)': [('Sound of Music, The (1965)', 1.0)],
#  'Crash (1996)': [('Scream (1996)', 1.0), ('Edge, The (1997)', 1.0)],
#  'Crimson Tide (1995)': [('Mallrats (1995)', 1.0)],
#  'Crucible, The (1996)': [('Career Girls (1997)', 1.0),
#   ('Thousand Acres, A (1997)', 1.0)],
#  'Crumb (1994)': [('Vertigo (1958)', 1.0)],
#  'Crying Game, The (1992)': [('Babe (1995)', 1.0)],
#  'Curdled (1996)': [('Mirror Has Two Faces, The (1996)', 1.0)],
#  'Dances with Wolves (1990)': [('Brazil (1985)', 1.0)],
#  'Dangerous Minds (1995)': [('Amistad (1997)', 1.0)],
#  "Dante's Peak (1997)": [('North by Northwest (1959)', 1.0),
#   ('Hard Rain (1998)', 1.0),
#   ('Beautician and the Beast, The (1997)', 1.0),
#   ('George of the Jungle (1997)', 1.0),
#   ("My Best Friend's Wedding (1997)", 1.0)],
#  'Dead Man (1995)': [('Big Night (1996)', 1.0)],
#  'Dead Man Walking (1995)': [('Evita (1996)', 1.0),
#   ('Shining, The (1980)', 1.0),
#   ('Up Close and Personal (1996)', 1.0)],
#  'Dead Poets Society (1989)': [('Renaissance Man (1994)', 1.0),
#   ('Taxi Driver (1976)', 1.0)],
#  'Deceiver (1997)': [('Contact (1997)', 1.0)],
#  'Deconstructing Harry (1997)': [('Batman Returns (1992)', 1.0)],
#  'Desperate Measures (1998)': [('English Patient, The (1996)', 1.0),
#   ('Wag the Dog (1997)', 1.0)],
#  'Devil in a Blue Dress (1995)': [('Clear and Present Danger (1994)', 1.0)],
#  "Devil's Advocate, The (1997)": [('Leave It to Beaver (1997)', 1.0),
#   ('Star Wars (1977)', 1.0),
#   ('Seven Years in Tibet (1997)', 0.9899494936611665)],
#  "Devil's Own, The (1997)": [('Contact (1997)', 1.0),
#   ('Playing God (1997)', 1.0),
#   ('Sleepers (1996)', 1.0),
#   ('Grand Day Out, A (1992)', 1.0),
#   ('Rock, The (1996)', 1.0),
#   ('Boot, Das (1981)', 1.0)],
#  'Diabolique (1996)': [('Fan, The (1996)', 1.0),
#   ('Crying Game, The (1992)', 1.0)],
#  'Dial M for Murder (1954)': [('Lawrence of Arabia (1962)', 1.0),
#   ('My Own Private Idaho (1991)', 1.0),
#   ('Brazil (1985)', 1.0)],
#  'Die Hard (1988)': [('Star Trek III: The Search for Spock (1984)', 1.0),
#   ('Pump Up the Volume (1990)', 1.0),
#   ('Flirting With Disaster (1996)', 1.0),
#   ('Pulp Fiction (1994)', 1.0),
#   ("McHale's Navy (1997)", 1.0)],
#  'Die xue shuang xiong (Killer, The) (1989)': [('Escape from New York (1981)',
#    1.0)],
#  'Dingo (1992)': [('Birdcage, The (1996)', 1.0)],
#  'Dolores Claiborne (1994)': [('Romeo Is Bleeding (1993)', 1.0)],
#  'Donnie Brasco (1997)': [('Return of the Jedi (1983)', 1.0),
#   ('Liar Liar (1997)', 1.0)],
#  'Down Periscope (1996)': [('Smoke (1995)', 1.0),
#   ('That Darn Cat! (1997)', 1.0)],
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)': [('Casper (1995)',
#    1.0),
#   ('Birds, The (1963)', 1.0),
#   ('In the Name of the Father (1993)', 1.0)],
#  'Dracula: Dead and Loving It (1995)': [('Heat (1995)', 1.0)],
#  'Dumb & Dumber (1994)': [('Beavis and Butt-head Do America (1996)', 1.0)],
#  'E.T. the Extra-Terrestrial (1982)': [('Batman (1989)', 1.0)],
#  'East of Eden (1955)': [('Henry V (1989)', 1.0)],
#  'Ed Wood (1994)': [('Return of the Pink Panther, The (1974)', 1.0),
#   ('Menace II Society (1993)', 1.0)],
#  'Edge, The (1997)': [("Antonia's Line (1995)", 1.0),
#   ('English Patient, The (1996)', 1.0)],
#  'Emma (1996)': [('Boot, Das (1981)', 1.0),
#   ('Nikita (La Femme Nikita) (1990)', 1.0),
#   ('Piano, The (1993)', 1.0)],
#  'Empire Strikes Back, The (1980)': [('Glory (1989)', 1.0),
#   ('Rock, The (1996)', 1.0),
#   ('Butch Cassidy and the Sundance Kid (1969)', 1.0)],
#  'Endless Summer 2, The (1994)': [('20,000 Leagues Under the Sea (1954)',
#    1.0)],
#  'English Patient, The (1996)': [('Fargo (1996)', 1.0),
#   ('Monty Python and the Holy Grail (1974)', 1.0),
#   ('Piano, The (1993)', 1.0),
#   ("Dante's Peak (1997)", 1.0),
#   ('Jerry Maguire (1996)', 1.0),
#   ('Good Will Hunting (1997)', 1.0),
#   ('Saint, The (1997)', 1.0),
#   ('Murder at 1600 (1997)', 1.0),
#   ('Starship Troopers (1997)', 0.9999999999999998)],
#  'Eraser (1996)': [('Terminator, The (1984)', 1.0),
#   ('Tin Cup (1996)', 1.0),
#   ('GoldenEye (1995)', 1.0)],
#  'Everyone Says I Love You (1996)': [('Cop Land (1997)', 1.0),
#   ('Saint, The (1997)', 1.0),
#   ('Liar Liar (1997)', 1.0),
#   ('Mother (1996)', 1.0),
#   ('Dial M for Murder (1954)', 1.0),
#   ('Star Wars (1977)', 1.0),
#   ('To Die For (1995)', 1.0)],
#  'Evil Dead II (1987)': [('City of Lost Children, The (1995)', 1.0)],
#  'Evita (1996)': [('Conspiracy Theory (1997)', 1.0),
#   ('Full Monty, The (1997)', 1.0),
#   ('Volcano (1997)', 1.0),
#   ('Wag the Dog (1997)', 1.0),
#   ('Hoodlum (1997)', 1.0),
#   ('187 (1997)', 1.0)],
#  'Excess Baggage (1997)': [('Terminator 2: Judgment Day (1991)', 1.0)],
#  'Executive Decision (1996)': [('James and the Giant Peach (1996)', 1.0)],
#  'Face/Off (1997)': [('Game, The (1997)', 1.0),
#   ('Kiss the Girls (1997)', 1.0),
#   ('Princess Bride, The (1987)', 1.0),
#   ('Contact (1997)', 1.0),
#   ('Dark City (1998)', 1.0)],
#  'FairyTale: A True Story (1997)': [('Wedding Singer, The (1998)', 1.0)],
#  'Faithful (1996)': [('Fantasia (1940)', 1.0)],
#  'Fallen (1998)': [('Edge, The (1997)', 1.0)],
#  'Family Thing, A (1996)': [('Mimic (1997)', 1.0)],
#  'Fan, The (1996)': [('Spitfire Grill, The (1996)', 1.0)],
#  'Fantasia (1940)': [('Clockwork Orange, A (1971)', 1.0),
#   ('Up Close and Personal (1996)', 1.0)],
#  'Fargo (1996)': [('Fierce Creatures (1997)', 1.0),
#   ('Terminator 2: Judgment Day (1991)', 1.0),
#   ('Seven Years in Tibet (1997)', 1.0),
#   ('Wings of Desire (1987)', 1.0),
#   ('Mimic (1997)', 1.0),
#   ('Independence Day (ID4) (1996)', 1.0),
#   ('Saint, The (1997)', 0.9486832980505138)],
#  'Fast, Cheap & Out of Control (1997)': [("Devil's Advocate, The (1997)",
#    1.0)],
#  'Father of the Bride (1950)': [('Kull the Conqueror (1997)', 1.0)],
#  'Father of the Bride Part II (1995)': [('Chinatown (1974)', 1.0),
#   ('Glimmer Man, The (1996)', 1.0)],
#  'Faust (1994)': [('This Is Spinal Tap (1984)', 1.0)],
#  'Feeling Minnesota (1996)': [('Fargo (1996)', 1.0),
#   ("Jackie Chan's First Strike (1996)", 1.0)],
#  'Field of Dreams (1989)': [('Murder at 1600 (1997)', 1.0)],
#  'Fierce Creatures (1997)': [('Psycho (1960)', 1.0)],
#  'Fifth Element, The (1997)': [('Tomorrow Never Dies (1997)', 1.0)],
#  'Fire Down Below (1997)': [('L.A. Confidential (1997)', 1.0)],
#  'First Wives Club, The (1996)': [('Primal Fear (1996)', 1.0),
#   ('Evening Star, The (1996)', 1.0),
#   ('Tin Cup (1996)', 1.0),
#   ('That Thing You Do! (1996)', 1.0),
#   ('Grumpier Old Men (1995)', 1.0)],
#  'Fled (1996)': [('Fly Away Home (1996)', 1.0)],
#  'Flubber (1997)': [('Edge, The (1997)', 1.0), ('In & Out (1997)', 1.0)],
#  'Fly Away Home (1996)': [('Mary Poppins (1964)', 1.0),
#   ('Murder at 1600 (1997)', 1.0),
#   ('Scream (1996)', 1.0),
#   ('As Good As It Gets (1997)', 1.0)],
#  'Fools Rush In (1997)': [('Full Monty, The (1997)', 1.0)],
#  'Foreign Correspondent (1940)': [("Singin' in the Rain (1952)", 1.0)],
#  'Forrest Gump (1994)': [("Singin' in the Rain (1952)", 1.0)],
#  'Four Rooms (1995)': [('French Kiss (1995)', 1.0)],
#  'Four Weddings and a Funeral (1994)': [('Hamlet (1996)', 1.0),
#   ('Heathers (1989)', 1.0)],
#  'French Twist (Gazon maudit) (1995)': [('Sabrina (1954)', 1.0)],
#  'Fried Green Tomatoes (1991)': [('Dead Poets Society (1989)', 1.0)],
#  'Frighteners, The (1996)': [('Cinderella (1950)', 1.0),
#   ('Volcano (1997)', 1.0)],
#  'Full Metal Jacket (1987)': [('Scream (1996)', 1.0), ('Glory (1989)', 1.0)],
#  'Full Monty, The (1997)': [('Air Force One (1997)', 1.0),
#   ('English Patient, The (1996)', 1.0),
#   ("Mr. Holland's Opus (1995)", 1.0),
#   ('Michael Collins (1996)', 1.0),
#   ("Devil's Advocate, The (1997)", 1.0)],
#  'G.I. Jane (1997)': [('Midnight in the Garden of Good and Evil (1997)', 1.0),
#   ('Fallen (1998)', 1.0)],
#  'Game, The (1997)': [('Starship Troopers (1997)', 1.0),
#   ('G.I. Jane (1997)', 1.0),
#   ('Mother (1996)', 1.0),
#   ('Liar Liar (1997)', 1.0),
#   ('Contact (1997)', 0.9946917938265513)],
#  'Gandhi (1982)': [('Addicted to Love (1997)', 1.0),
#   ('Full Metal Jacket (1987)', 1.0)],
#  'Gattaca (1997)': [('187 (1997)', 1.0)],
#  'George of the Jungle (1997)': [('Jerry Maguire (1996)', 1.0),
#   ('Mission: Impossible (1996)', 1.0)],
#  'Germinal (1993)': [('Ballad of Narayama, The (Narayama Bushiko) (1958)',
#    1.0)],
#  'Get Shorty (1995)': [('E.T. the Extra-Terrestrial (1982)', 1.0),
#   ('Chasing Amy (1997)', 1.0),
#   ('Evita (1996)', 1.0),
#   ('Butch Cassidy and the Sundance Kid (1969)', 1.0),
#   ('Brazil (1985)', 1.0)],
#  'Ghost and Mrs. Muir, The (1947)': [('Fantasia (1940)', 1.0)],
#  'Glimmer Man, The (1996)': [('Absolute Power (1997)', 1.0)],
#  'Godfather, The (1972)': [('Terminator 2: Judgment Day (1991)', 1.0),
#   ('Mission: Impossible (1996)', 1.0),
#   ('Rear Window (1954)', 1.0),
#   ('Air Force One (1997)', 1.0),
#   ('Broken Arrow (1996)', 1.0),
#   ('Gandhi (1982)', 1.0),
#   ('Star Wars (1977)', 1.0)],
#  'GoldenEye (1995)': [('From Dusk Till Dawn (1996)', 1.0),
#   ('That Thing You Do! (1996)', 1.0),
#   ('Pulp Fiction (1994)', 1.0)],
#  'Gone with the Wind (1939)': [('Home for the Holidays (1995)', 1.0)],
#  'Good Will Hunting (1997)': [('Scream (1996)', 1.0),
#   ('English Patient, The (1996)', 1.0),
#   ('Sphere (1998)', 1.0)],
#  'Good, The Bad and The Ugly, The (1966)': [('Robin Hood: Men in Tights (1993)',
#    1.0),
#   ('Alien 3 (1992)', 1.0),
#   ('Mirror Has Two Faces, The (1996)', 1.0)],
#  'GoodFellas (1990)': [('House of the Spirits, The (1993)', 1.0),
#   ('Ghost and the Darkness, The (1996)', 1.0),
#   ('Private Parts (1997)', 1.0)],
#  'Goofy Movie, A (1995)': [('Quest, The (1996)', 1.0)],
#  'Graduate, The (1967)': [('Crumb (1994)', 1.0),
#   ('Miracle on 34th Street (1994)', 1.0)],
#  'Grease (1978)': [('Roman Holiday (1953)', 1.0),
#   ('To Kill a Mockingbird (1962)', 1.0)],
#  'Great Dictator, The (1940)': [('Big Lebowski, The (1998)', 1.0)],
#  'Great Escape, The (1963)': [('Raiders of the Lost Ark (1981)', 1.0)],
#  'Great Expectations (1998)': [('Liar Liar (1997)', 1.0)],
#  'Great Race, The (1965)': [('Manhattan (1979)', 1.0)],
#  'Groundhog Day (1993)': [('Hoop Dreams (1994)', 1.0),
#   ('Wallace & Gromit: The Best of Aardman Animation (1996)', 1.0),
#   ('Showgirls (1995)', 1.0)],
#  'Grumpier Old Men (1995)': [('Return of the Jedi (1983)', 1.0),
#   ('Godfather, The (1972)', 1.0),
#   ('Craft, The (1996)', 1.0)],
#  'Harold and Maude (1971)': [('Blues Brothers, The (1980)', 1.0)],
#  'Heat (1995)': [('Empire Strikes Back, The (1980)', 1.0),
#   ('Celluloid Closet, The (1995)', 1.0),
#   ('Seven Years in Tibet (1997)', 1.0),
#   ('Mighty Aphrodite (1995)', 1.0),
#   ('Star Trek: First Contact (1996)', 1.0),
#   ('Peacemaker, The (1997)', 1.0)],
#  'Heathers (1989)': [('Patton (1970)', 1.0)],
#  'Heavenly Creatures (1994)': [('Mary Reilly (1996)', 1.0)],
#  'Heavyweights (1994)': [('Houseguest (1994)', 1.0)],
#  'Henry V (1989)': [('Brazil (1985)', 1.0)],
#  'High Noon (1952)': [('Paths of Glory (1957)', 1.0)],
#  'His Girl Friday (1940)': [('M*A*S*H (1970)', 1.0)],
#  'Home Alone (1990)': [('M*A*S*H (1970)', 1.0),
#   ('Toy Story (1995)', 1.0),
#   ('Free Willy (1993)', 1.0)],
#  'Home Alone 3 (1997)': [('While You Were Sleeping (1995)', 1.0)],
#  'Hoop Dreams (1994)': [('Vertigo (1958)', 1.0)],
#  'House Arrest (1996)': [("Joe's Apartment (1996)", 1.0)],
#  'How to Be a Player (1997)': [("Devil's Own, The (1997)", 1.0)],
#  'How to Make an American Quilt (1995)': [('Matilda (1996)', 1.0)],
#  'Howling, The (1981)': [('Twelve Monkeys (1995)', 1.0)],
#  'Hudsucker Proxy, The (1994)': [('Con Air (1997)', 1.0)],
#  'Hugo Pool (1997)': [('Spice World (1997)', 1.0)],
#  'Hunt for Red October, The (1990)': [('Apollo 13 (1995)', 1.0),
#   ('Angels and Insects (1995)', 1.0),
#   ('Taxi Driver (1976)', 1.0),
#   ('Great Escape, The (1963)', 1.0)],
#  'I Know What You Did Last Summer (1997)': [('Time to Kill, A (1996)', 1.0),
#   ('Edge, The (1997)', 1.0),
#   ('Scream 2 (1997)', 1.0)],
#  'Ice Storm, The (1997)': [('Man Who Knew Too Little, The (1997)', 1.0)],
#  'In & Out (1997)': [("Mr. Holland's Opus (1995)", 1.0),
#   ('Executive Decision (1996)', 1.0),
#   ('Rosewood (1997)', 1.0),
#   ('Raiders of the Lost Ark (1981)', 1.0),
#   ('Peacemaker, The (1997)', 1.0)],
#  'In the Company of Men (1997)': [('Manon of the Spring (Manon des sources) (1986)',
#    1.0)],
#  'In the Line of Fire (1993)': [('Demolition Man (1993)', 1.0)],
#  'Independence Day (ID4) (1996)': [('Ghost and the Darkness, The (1996)',
#    1.0)],
#  'Indiana Jones and the Last Crusade (1989)': [('2001: A Space Odyssey (1968)',
#    1.0)],
#  'Interview with the Vampire (1994)': [('Dazed and Confused (1993)', 1.0)],
#  'Island of Dr. Moreau, The (1996)': [('Private Parts (1997)', 1.0),
#   ('Diabolique (1996)', 1.0)],
#  "It's a Wonderful Life (1946)": [('Lone Star (1996)', 1.0),
#   ('Mimic (1997)', 1.0),
#   ('Star Wars (1977)', 1.0),
#   ("Marvin's Room (1996)", 1.0)],
#  'Jackal, The (1997)': [('Rocket Man (1997)', 1.0), ('Cop Land (1997)', 1.0)],
#  'Jackie Brown (1997)': [('Liar Liar (1997)', 1.0),
#   ('Conspiracy Theory (1997)', 1.0),
#   ('Rosewood (1997)', 1.0)],
#  "Jackie Chan's First Strike (1996)": [('Independence Day (ID4) (1996)', 1.0)],
#  'Jaws (1975)': [('Secrets & Lies (1996)', 1.0),
#   ('Last Man Standing (1996)', 1.0),
#   ('Raiders of the Lost Ark (1981)', 1.0),
#   ('Angels in the Outfield (1994)', 1.0),
#   ('Wild Bunch, The (1969)', 1.0)],
#  'Jaws 2 (1978)': [('French Kiss (1995)', 1.0), ('Birdcage, The (1996)', 1.0)],
#  'Jean de Florette (1986)': [('Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)',
#    1.0),
#   ('Chasing Amy (1997)', 1.0)],
#  'Jerry Maguire (1996)': [('Die Hard (1988)', 1.0),
#   ('Michael Collins (1996)', 1.0),
#   ('Full Monty, The (1997)', 1.0),
#   ('Frighteners, The (1996)', 1.0)],
#  'Jumanji (1995)': [('Independence Day (ID4) (1996)', 1.0)],
#  'Jungle Book, The (1994)': [('George of the Jungle (1997)', 1.0)],
#  'Jungle2Jungle (1997)': [('Fire Down Below (1997)', 1.0)],
#  'Jurassic Park (1993)': [('Wag the Dog (1997)', 1.0),
#   ('Man Without a Face, The (1993)', 1.0),
#   ('Back to the Future (1985)', 1.0)],
#  'Just Cause (1995)': [('Twister (1996)', 1.0)],
#  'Kaspar Hauser (1993)': [("Monty Python's Life of Brian (1979)", 1.0)],
#  'Kids (1995)': [('Wrong Trousers, The (1993)', 1.0)],
#  'Kingpin (1996)': [('Game, The (1997)', 1.0)],
#  'Kiss Me, Guido (1997)': [('Saint, The (1997)', 1.0)],
#  'Kiss the Girls (1997)': [('Chasing Amy (1997)', 1.0),
#   ('Full Monty, The (1997)', 1.0),
#   ('Grosse Pointe Blank (1997)', 1.0),
#   ('Contact (1997)', 1.0)],
#  'Kissed (1996)': [('Fifth Element, The (1997)', 1.0)],
#  'Kolya (1996)': [('Mrs. Doubtfire (1993)', 1.0),
#   ('Pulp Fiction (1994)', 1.0),
#   ("Eve's Bayou (1997)", 1.0)],
#  'Kull the Conqueror (1997)': [('Star Trek: The Wrath of Khan (1982)', 1.0),
#   ('Ransom (1996)', 1.0)],
#  'L.A. Confidential (1997)': [('Princess Bride, The (1987)', 1.0),
#   ('English Patient, The (1996)', 1.0),
#   ('Cold Comfort Farm (1995)', 1.0),
#   ('Clear and Present Danger (1994)', 1.0),
#   ("Dante's Peak (1997)", 1.0),
#   ('As Good As It Gets (1997)', 1.0)],
#  'Last Action Hero (1993)': [('Mission: Impossible (1996)', 1.0)],
#  'Last of the Mohicans, The (1992)': [('Full Metal Jacket (1987)', 1.0),
#   ('Terminator 2: Judgment Day (1991)', 1.0)],
#  'Lawrence of Arabia (1962)': [('Indiana Jones and the Last Crusade (1989)',
#    1.0)],
#  'Leaving Las Vegas (1995)': [('Babe (1995)', 1.0),
#   ('Mission: Impossible (1996)', 1.0),
#   ('Bottle Rocket (1996)', 1.0)],
#  'Legends of the Fall (1994)': [('One Fine Day (1996)', 1.0),
#   ('Abyss, The (1989)', 1.0)],
#  'Liar Liar (1997)': [("Preacher's Wife, The (1996)", 1.0),
#   ('Mother (1996)', 1.0),
#   ('Star Trek: Generations (1994)', 1.0),
#   ('Scream (1996)', 1.0),
#   ('Hoop Dreams (1994)', 1.0),
#   ('Othello (1995)', 1.0),
#   ('Evita (1996)', 1.0),
#   ('Fierce Creatures (1997)', 1.0)],
#  'Life Less Ordinary, A (1997)': [('Maltese Falcon, The (1941)', 1.0)],
#  'Like Water For Chocolate (Como agua para chocolate) (1992)': [('Groundhog Day (1993)',
#    1.0),
#   ('Gone with the Wind (1939)', 1.0)],
#  'Lion King, The (1994)': [('Blob, The (1958)', 1.0),
#   ('Close Shave, A (1995)', 1.0),
#   ("Sophie's Choice (1982)", 1.0)],
#  'Little Big League (1994)': [("William Shakespeare's Romeo and Juliet (1996)",
#    1.0)],
#  'Little Princess, A (1995)': [('Speed (1994)', 1.0)],
#  'Lone Star (1996)': [('Multiplicity (1996)', 1.0)],
#  'Long Kiss Goodnight, The (1996)': [('Lone Star (1996)', 1.0)],
#  'Lost Highway (1997)': [('Mission: Impossible (1996)', 1.0),
#   ('Kiss Me, Guido (1997)', 1.0),
#   ('Shallow Grave (1994)', 1.0)],
#  'Lost World: Jurassic Park, The (1997)': [('Father of the Bride Part II (1995)',
#    1.0)],
#  'Love & Human Remains (1993)': [('Pulp Fiction (1994)', 1.0)],
#  'Love Jones (1997)': [("Devil's Advocate, The (1997)", 1.0),
#   ('Contact (1997)', 1.0)],
#  'Love! Valour! Compassion! (1997)': [('Nine Months (1995)', 1.0)],
#  'Ma vie en rose (My Life in Pink) (1997)': [('Rosewood (1997)', 1.0)],
#  'Mad City (1997)': [('Great Expectations (1998)', 1.0),
#   ('Saint, The (1997)', 1.0)],
#  'Madness of King George, The (1994)': [('Clockwork Orange, A (1971)', 1.0)],
#  'Maltese Falcon, The (1941)': [("Miller's Crossing (1990)", 1.0)],
#  'Man Without a Face, The (1993)': [('Backbeat (1993)', 1.0),
#   ("Muriel's Wedding (1994)", 1.0)],
#  'Man in the Iron Mask, The (1998)': [('Grosse Pointe Blank (1997)', 1.0)],
#  'Manhattan (1979)': [('Blue in the Face (1995)', 1.0)],
#  'Mars Attacks! (1996)': [('Philadelphia Story, The (1940)', 1.0),
#   ("Marvin's Room (1996)", 1.0),
#   ('Die Hard: With a Vengeance (1995)', 1.0)],
#  "Marvin's Room (1996)": [('Saint, The (1997)', 1.0)],
#  'Mary Poppins (1964)': [('Bride of Frankenstein (1935)', 1.0)],
#  'Mask, The (1994)': [('Arsenic and Old Lace (1944)', 1.0)],
#  'MatchMaker, The (1997)': [('Rosewood (1997)', 1.0)],
#  'Matilda (1996)': [('In & Out (1997)', 1.0)],
#  'Maverick (1994)': [('Shawshank Redemption, The (1994)', 1.0)],
#  "McHale's Navy (1997)": [('Game, The (1997)', 1.0)],
#  'Mediterraneo (1991)': [("Muriel's Wedding (1994)", 1.0)],
#  'Men With Guns (1997)': [("Eve's Bayou (1997)", 1.0)],
#  'Men in Black (1997)': [("My Best Friend's Wedding (1997)", 1.0),
#   ('African Queen, The (1951)', 1.0),
#   ('Truth About Cats & Dogs, The (1996)', 1.0),
#   ('Sling Blade (1996)', 1.0)],
#  'Michael (1996)': [('Star Wars (1977)', 1.0)],
#  'Michael Collins (1996)': [('Jerry Maguire (1996)', 1.0)],
#  'Midnight in the Garden of Good and Evil (1997)': [('Kolya (1996)', 1.0),
#   ('Postman, The (1997)', 1.0)],
#  'Mighty Aphrodite (1995)': [('People vs. Larry Flynt, The (1996)', 1.0),
#   ('Willy Wonka and the Chocolate Factory (1971)', 1.0)],
#  "Miller's Crossing (1990)": [('Kingpin (1996)', 1.0)],
#  'Mimic (1997)': [("Ulee's Gold (1997)", 1.0)],
#  'Mission: Impossible (1996)': [('MatchMaker, The (1997)', 1.0),
#   ('Ransom (1996)', 1.0)],
#  'Money Talks (1997)': [('Liar Liar (1997)', 1.0)],
#  'Monty Python and the Holy Grail (1974)': [('Searching for Bobby Fischer (1993)',
#    1.0)],
#  "Monty Python's Life of Brian (1979)": [('Bogus (1996)', 1.0),
#   ('Killing Fields, The (1984)', 1.0)],
#  'Mortal Kombat: Annihilation (1997)': [('Scream 2 (1997)', 1.0)],
#  'Mother (1996)': [('Scream (1996)', 1.0),
#   ('Courage Under Fire (1996)', 1.0),
#   ('Beautician and the Beast, The (1997)', 1.0)],
#  'Mouse Hunt (1997)': [('Butch Cassidy and the Sundance Kid (1969)', 1.0)],
#  "Mr. Holland's Opus (1995)": [('Hamlet (1996)', 1.0),
#   ('One Night Stand (1997)', 1.0)],
#  'Mrs. Brown (Her Majesty, Mrs. Brown) (1997)': [('Mother (1996)', 1.0),
#   ('Shine (1996)', 1.0)],
#  'Much Ado About Nothing (1993)': [('Being There (1979)', 1.0)],
#  'Multiplicity (1996)': [('Spitfire Grill, The (1996)', 1.0),
#   ('Bullets Over Broadway (1994)', 1.0),
#   ('Swingers (1996)', 1.0),
#   ("Jackie Chan's First Strike (1996)", 1.0)],
#  'Muppet Treasure Island (1996)': [('Star Trek IV: The Voyage Home (1986)',
#    1.0)],
#  'Murder at 1600 (1997)': [('Anna Karenina (1997)', 1.0),
#   ('Courage Under Fire (1996)', 1.0),
#   ("Ulee's Gold (1997)", 1.0)],
#  'My Fair Lady (1964)': [('Back to the Future (1985)', 1.0),
#   ('Sneakers (1992)', 1.0),
#   ('Ghost (1990)', 1.0)],
#  'My Family (1995)': [('Island of Dr. Moreau, The (1996)', 1.0)],
#  'My Fellow Americans (1996)': [('Cable Guy, The (1996)', 1.0)],
#  'My Own Private Idaho (1991)': [('Aliens (1986)', 1.0)],
#  'Mystery Science Theater 3000: The Movie (1996)': [('Bride of Frankenstein (1935)',
#    1.0),
#   ('Starship Troopers (1997)', 1.0)],
#  'Naked Gun 33 1/3: The Final Insult (1994)': [('Ace Ventura: When Nature Calls (1995)',
#    1.0),
#   ('Con Air (1997)', 1.0)],
#  'Nightmare on Elm Street, A (1984)': [('Tales from the Hood (1995)', 1.0)],
#  'Nixon (1995)': [('First Wives Club, The (1996)', 1.0),
#   ('Big Night (1996)', 1.0)],
#  'North by Northwest (1959)': [('Akira (1988)', 1.0),
#   ('Rear Window (1954)', 1.0),
#   ('Speed (1994)', 1.0)],
#  'Nothing to Lose (1994)': [('Bottle Rocket (1996)', 1.0)],
#  'Nutty Professor, The (1996)': [('Sgt. Bilko (1996)', 1.0)],
#  'One Fine Day (1996)': [('Up Close and Personal (1996)', 1.0)],
#  "One Flew Over the Cuckoo's Nest (1975)": [('Beauty and the Beast (1991)',
#    1.0),
#   ('Kolya (1996)', 1.0)],
#  'Only You (1994)': [('City of Lost Children, The (1995)', 1.0)],
#  'Oscar & Lucinda (1997)': [('Shall We Dance? (1996)', 1.0)],
#  'Outbreak (1995)': [('Gone with the Wind (1939)', 1.0)],
#  'Pallbearer, The (1996)': [('Happy Gilmore (1996)', 1.0)],
#  'Paper, The (1994)': [('Pulp Fiction (1994)', 1.0)],
#  'Patton (1970)': [('This Is Spinal Tap (1984)', 1.0)],
#  'Peacemaker, The (1997)': [('Titanic (1997)', 1.0), ('Volcano (1997)', 1.0)],
#  'People vs. Larry Flynt, The (1996)': [('Crying Game, The (1992)', 1.0),
#   ('Time to Kill, A (1996)', 1.0)],
#  "Pete's Dragon (1977)": [('Highlander III: The Sorcerer (1994)', 1.0),
#   ('Game, The (1997)', 1.0)],
#  'Phenomenon (1996)': [('Postino, Il (1994)', 1.0),
#   ('Circle of Friends (1995)', 1.0)],
#  'Philadelphia (1993)': [('Manhattan (1979)', 1.0)],
#  'Piano, The (1993)': [('Star Wars (1977)', 1.0)],
#  'Picture Perfect (1997)': [('Liar Liar (1997)', 1.0),
#   ('Edge, The (1997)', 1.0)],
#  'Pinocchio (1940)': [("Wes Craven's New Nightmare (1994)", 1.0)],
#  'Playing God (1997)': [('Titanic (1997)', 1.0)],
#  'Postino, Il (1994)': [('Being There (1979)', 1.0),
#   ('Big Night (1996)', 1.0)],
#  'Postman, The (1997)': [('George of the Jungle (1997)', 1.0)],
#  "Preacher's Wife, The (1996)": [('Hunchback of Notre Dame, The (1996)', 1.0)],
#  'Princess Bride, The (1987)': [('Time to Kill, A (1996)', 1.0)],
#  'Private Parts (1997)': [('Fifth Element, The (1997)', 1.0),
#   ('Godfather, The (1972)', 1.0)],
#  'Professional, The (1994)': [('Real Genius (1985)', 1.0)],
#  'Psycho (1960)': [('Star Trek IV: The Voyage Home (1986)', 1.0)],
#  'Pulp Fiction (1994)': [('Hunt for Red October, The (1990)', 1.0),
#   ('Red Firecracker, Green Firecracker (1994)', 1.0),
#   ("Fathers' Day (1997)", 1.0),
#   ('Long Kiss Goodnight, The (1996)', 1.0),
#   ('My Favorite Year (1982)', 1.0),
#   ('Princess Bride, The (1987)', 1.0)],
#  'Quest, The (1996)': [('Dragonheart (1996)', 1.0),
#   ('Independence Day (ID4) (1996)', 1.0)],
#  'Quiz Show (1994)': [('Truth About Cats & Dogs, The (1996)', 1.0),
#   ('Rear Window (1954)', 1.0)],
#  'Raiders of the Lost Ark (1981)': [('Volcano (1997)', 1.0),
#   ('Private Benjamin (1980)', 1.0),
#   ('Sabrina (1995)', 1.0),
#   ('Toy Story (1995)', 1.0)],
#  'Rainmaker, The (1997)': [('Winter Guest, The (1997)', 1.0),
#   ('Mouse Hunt (1997)', 1.0)],
#  'Raising Arizona (1987)': [('Terminator, The (1984)', 1.0),
#   ('Forget Paris (1995)', 1.0),
#   ('Top Gun (1986)', 1.0)],
#  'Ransom (1996)': [('Godfather, The (1972)', 1.0),
#   ('Apocalypse Now (1979)', 1.0),
#   ('Hunchback of Notre Dame, The (1996)', 1.0)],
#  'Real Genius (1985)': [('Highlander (1986)', 1.0)],
#  'Reality Bites (1994)': [('Brady Bunch Movie, The (1995)', 1.0),
#   ('Home Alone (1990)', 1.0)],
#  'Rear Window (1954)': [('Wings of the Dove, The (1997)', 1.0),
#   ('Toy Story (1995)', 1.0)],
#  'Red Corner (1997)': [('Mimic (1997)', 1.0)],
#  'Red Rock West (1992)': [('Piano, The (1993)', 1.0)],
#  'Remains of the Day, The (1993)': [('Postino, Il (1994)', 1.0),
#   ('Sling Blade (1996)', 1.0)],
#  'Renaissance Man (1994)': [('Shawshank Redemption, The (1994)', 1.0)],
#  'Rent-a-Kid (1995)': [('Demolition Man (1993)', 1.0)],
#  'Reservoir Dogs (1992)': [('Searching for Bobby Fischer (1993)', 1.0)],
#  'Restoration (1995)': [('Kolya (1996)', 1.0), ('Air Force One (1997)', 1.0)],
#  'Return of the Jedi (1983)': [('Promesse, La (1996)', 1.0),
#   ('U Turn (1997)', 1.0),
#   ('Godfather, The (1972)', 1.0),
#   ('Horse Whisperer, The (1998)', 1.0),
#   ('Die Hard (1988)', 1.0),
#   ("One Flew Over the Cuckoo's Nest (1975)", 1.0),
#   ('Cat on a Hot Tin Roof (1958)', 1.0)],
#  'Return of the Pink Panther, The (1974)': [('Broken Arrow (1996)', 1.0)],
#  'Richard III (1995)': [('Pillow Book, The (1995)', 1.0),
#   ('Graduate, The (1967)', 1.0),
#   ('Gandhi (1982)', 1.0),
#   ('Cop Land (1997)', 1.0)],
#  'Right Stuff, The (1983)': [('Homeward Bound: The Incredible Journey (1993)',
#    1.0),
#   ('Speed (1994)', 1.0),
#   ('Jerry Maguire (1996)', 1.0),
#   ('Night of the Living Dead (1968)', 1.0)],
#  'River Wild, The (1994)': [('Rumble in the Bronx (1995)', 1.0)],
#  'Robin Hood: Prince of Thieves (1991)': [('Cold Comfort Farm (1995)', 1.0)],
#  'Rock, The (1996)': [("My Best Friend's Wedding (1997)", 1.0),
#   ('Time to Kill, A (1996)', 1.0),
#   ('Jerry Maguire (1996)', 1.0),
#   ('Dragonheart (1996)', 1.0),
#   ('Shining, The (1980)', 1.0),
#   ('Philadelphia Story, The (1940)', 1.0),
#   ('Good, The Bad and The Ugly, The (1966)', 1.0)],
#  'Roman Holiday (1953)': [('My Life as a Dog (Mitt liv som hund) (1985)',
#    1.0)],
#  "Romy and Michele's High School Reunion (1997)": [('Young Frankenstein (1974)',
#    1.0)],
#  'Room with a View, A (1986)': [('Piano, The (1993)', 1.0)],
#  'Roommates (1995)': [('Trees Lounge (1996)', 1.0)],
#  'Rosewood (1997)': [('Contact (1997)', 1.0),
#   ("Devil's Own, The (1997)", 1.0),
#   ('Shall We Dance? (1996)', 1.0),
#   ('Mrs. Brown (Her Majesty, Mrs. Brown) (1997)', 1.0)],
#  'Rumble in the Bronx (1995)': [('Adventures of Pinocchio, The (1996)', 1.0),
#   ('Godfather, The (1972)', 1.0)],
#  'Sabrina (1954)': [('Rock, The (1996)', 1.0), ('Young Guns (1988)', 1.0)],
#  'Sabrina (1995)': [('Birdcage, The (1996)', 1.0),
#   ('Jean de Florette (1986)', 1.0),
#   ('Conspiracy Theory (1997)', 1.0)],
#  'Saint, The (1997)': [('Forrest Gump (1994)', 1.0),
#   ('Homeward Bound II: Lost in San Francisco (1996)', 1.0),
#   ('Lone Star (1996)', 1.0),
#   ('Fargo (1996)', 1.0),
#   ('Pretty Woman (1990)', 1.0)],
#  'Santa Clause, The (1994)': [('Clueless (1995)', 1.0)],
#  "Schindler's List (1993)": [('Cape Fear (1991)', 1.0),
#   ('Indiana Jones and the Last Crusade (1989)', 1.0),
#   ('Casablanca (1942)', 1.0)],
#  'Scream (1996)': [("Dante's Peak (1997)", 1.0),
#   ('Pulp Fiction (1994)', 1.0),
#   ('Stag (1997)', 1.0),
#   ('Everyone Says I Love You (1996)', 1.0),
#   ('Money Train (1995)', 1.0),
#   ('Lost Highway (1997)', 1.0),
#   ('Young Frankenstein (1974)', 1.0),
#   ('U Turn (1997)', 1.0),
#   ('I Know What You Did Last Summer (1997)', 1.0)],
#  'Searching for Bobby Fischer (1993)': [('Peacemaker, The (1997)', 1.0)],
#  'Secrets & Lies (1996)': [('Breaking the Waves (1996)', 1.0),
#   ('As Good As It Gets (1997)', 1.0),
#   ('Jerry Maguire (1996)', 1.0)],
#  'Sense and Sensibility (1995)': [('Dead Man Walking (1995)', 1.0),
#   ('Jerry Maguire (1996)', 1.0),
#   ('My Left Foot (1989)', 1.0)],
#  'Seven (Se7en) (1995)': [('Broken Arrow (1996)', 1.0),
#   ('Mr. Smith Goes to Washington (1939)', 1.0),
#   ('Natural Born Killers (1994)', 1.0)],
#  'Seven Years in Tibet (1997)': [('Life Less Ordinary, A (1997)', 1.0),
#   ('Air Force One (1997)', 1.0),
#   ('Fly Away Home (1996)', 1.0),
#   ('Liar Liar (1997)', 1.0),
#   ("She's the One (1996)", 1.0)],
#  'Shadow Conspiracy (1997)': [('Rock, The (1996)', 1.0)],
#  'Shadowlands (1993)': [('Tomorrow Never Dies (1997)', 1.0)],
#  'Shawshank Redemption, The (1994)': [('Amadeus (1984)', 1.0),
#   ('Alien (1979)', 1.0),
#   ('Long Kiss Goodnight, The (1996)', 1.0),
#   ('Indiana Jones and the Last Crusade (1989)', 1.0),
#   ('High School High (1996)', 1.0)],
#  "She's So Lovely (1997)": [('Lost Highway (1997)', 1.0)],
#  'Shine (1996)': [('Tango Lesson, The (1997)', 1.0)],
#  'Shining, The (1980)': [('Celluloid Closet, The (1995)', 1.0),
#   ('Prophecy, The (1995)', 1.0)],
#  'Short Cuts (1993)': [('Some Like It Hot (1959)', 1.0)],
#  'Silence of the Lambs, The (1991)': [('Mrs. Brown (Her Majesty, Mrs. Brown) (1997)',
#    1.0),
#   ('Eraser (1996)', 1.0),
#   ('Tommy Boy (1995)', 1.0),
#   ('Full Monty, The (1997)', 1.0)],
#  "Singin' in the Rain (1952)": [('People vs. Larry Flynt, The (1996)', 1.0)],
#  'Six Degrees of Separation (1993)': [('Die Hard (1988)', 1.0),
#   ('Roommates (1995)', 1.0),
#   ('Batman (1989)', 1.0)],
#  'Sleeper (1973)': [("Nobody's Fool (1994)", 1.0)],
#  'Sleepers (1996)': [('Mary Reilly (1996)', 1.0), ('Alien 3 (1992)', 1.0)],
#  'Sleepless in Seattle (1993)': [('Sound of Music, The (1965)', 1.0),
#   ('Kolya (1996)', 1.0)],
#  'Smile Like Yours, A (1997)': [('I Know What You Did Last Summer (1997)',
#    1.0)],
#  'Snow White and the Seven Dwarfs (1937)': [('Quiz Show (1994)', 1.0)],
#  'Some Like It Hot (1959)': [('Glory (1989)', 1.0)],
#  'Sound of Music, The (1965)': [('Cable Guy, The (1996)', 1.0)],
#  'Space Jam (1996)': [('Very Brady Sequel, A (1996)', 1.0)],
#  'Speed (1994)': [('In & Out (1997)', 1.0), ('Boys on the Side (1995)', 1.0)],
#  'Sphere (1998)': [('That Thing You Do! (1996)', 1.0)],
#  'Spitfire Grill, The (1996)': [('Breaking the Waves (1996)', 1.0),
#   ("Marvin's Room (1996)", 1.0)],
#  'Star Kid (1997)': [('Man Who Knew Too Little, The (1997)', 1.0)],
#  "Star Maker, The (Uomo delle stelle, L') (1995)": [('Sabrina (1954)', 1.0)],
#  'Star Trek III: The Search for Spock (1984)': [('Liar Liar (1997)', 1.0)],
#  'Star Trek: First Contact (1996)': [('Tin Cup (1996)', 1.0),
#   ('Starship Troopers (1997)', 1.0),
#   ('D3: The Mighty Ducks (1996)', 1.0),
#   ('Cape Fear (1962)', 1.0),
#   ('Breakdown (1997)', 1.0),
#   ('Hunchback of Notre Dame, The (1996)', 1.0)],
#  'Star Trek: Generations (1994)': [('Reality Bites (1994)', 1.0)],
#  'Star Trek: The Wrath of Khan (1982)': [('Groundhog Day (1993)', 1.0),
#   ('Birdcage, The (1996)', 1.0)],
#  'Star Wars (1977)': [('Breakdown (1997)', 1.0),
#   ('L.A. Confidential (1997)', 1.0),
#   ('City of Lost Children, The (1995)', 1.0),
#   ('Sense and Sensibility (1995)', 1.0),
#   ('E.T. the Extra-Terrestrial (1982)', 1.0),
#   ('Spy Hard (1996)', 1.0),
#   ('Tomorrow Never Dies (1997)', 1.0),
#   ('Jerry Maguire (1996)', 1.0)],
#  'Starship Troopers (1997)': [('Children of the Corn: The Gathering (1996)',
#    1.0),
#   ("Dante's Peak (1997)", 1.0)],
#  'Stealing Beauty (1996)': [('Bad Boys (1995)', 1.0)],
#  'Sting, The (1973)': [('Star Trek: The Wrath of Khan (1982)', 1.0),
#   ('Sound of Music, The (1965)', 1.0),
#   ('Alien (1979)', 1.0)],
#  'Stranger in the House (1997)': [('Game, The (1997)', 1.0)],
#  'Substitute, The (1996)': [('Eye for an Eye (1996)', 1.0)],
#  'Sunset Blvd. (1950)': [("Breakfast at Tiffany's (1961)", 1.0)],
#  'Swimming with Sharks (1995)': [('Assassins (1995)', 1.0)],
#  'Tales From the Crypt Presents: Demon Knight (1995)': [('Star Wars (1977)',
#    1.0),
#   ('When Harry Met Sally... (1989)', 1.0)],
#  'Tales from the Crypt Presents: Bordello of Blood (1996)': [('Craft, The (1996)',
#    1.0)],
#  'Taxi Driver (1976)': [("Marvin's Room (1996)", 1.0), ('Malice (1993)', 1.0)],
#  'Terminator 2: Judgment Day (1991)': [("Mr. Holland's Opus (1995)", 1.0),
#   ('James and the Giant Peach (1996)', 1.0),
#   ('Fools Rush In (1997)', 1.0),
#   ('Jackie Brown (1997)', 1.0),
#   ('Rock, The (1996)', 0.9486832980505138)],
#  'Terminator, The (1984)': [('Liar Liar (1997)', 1.0),
#   ('This Is Spinal Tap (1984)', 1.0)],
#  'That Darn Cat! (1965)': [('Abyss, The (1989)', 1.0)],
#  'That Thing You Do! (1996)': [('Forrest Gump (1994)', 1.0),
#   ('Mission: Impossible (1996)', 1.0)],
#  'Thin Man, The (1934)': [('Little Princess, A (1995)', 1.0)],
#  'Thinner (1996)': [('Chamber, The (1996)', 1.0)],
#  'Third Man, The (1949)': [('Diva (1981)', 1.0)],
#  'This Is Spinal Tap (1984)': [('Evil Dead II (1987)', 1.0),
#   ('Duck Soup (1933)', 1.0)],
#  'Three Colors: Red (1994)': [('Annie Hall (1977)', 1.0)],
#  'Three Colors: White (1994)': [('Grand Day Out, A (1992)', 1.0),
#   ('Brazil (1985)', 1.0)],
#  'Three Musketeers, The (1993)': [('Dead Poets Society (1989)', 1.0),
#   ('Mary Poppins (1964)', 1.0)],
#  'Time to Kill, A (1996)': [('Days of Thunder (1990)', 1.0),
#   ('Lost World: Jurassic Park, The (1997)', 1.0)],
#  'Tin Cup (1996)': [('Quiz Show (1994)', 1.0),
#   ('Star Trek: First Contact (1996)', 1.0),
#   ('Air Force One (1997)', 1.0),
#   ('Men in Black (1997)', 1.0),
#   ('Beavis and Butt-head Do America (1996)', 1.0)],
#  'Titanic (1997)': [('Pulp Fiction (1994)', 1.0),
#   ('Bean (1997)', 1.0),
#   ('Thousand Acres, A (1997)', 1.0),
#   ('Chasing Amy (1997)', 1.0)],
#  'To Die For (1995)': [('Bullets Over Broadway (1994)', 1.0)],
#  'To Gillian on Her 37th Birthday (1996)': [('Courage Under Fire (1996)',
#    1.0)],
#  'To Kill a Mockingbird (1962)': [('Three Colors: Blue (1993)', 1.0),
#   ('Streetcar Named Desire, A (1951)', 1.0),
#   ('Shine (1996)', 1.0)],
#  'To Wong Foo, Thanks for Everything! Julie Newmar (1995)': [('Back to the Future (1985)',
#    1.0)],
#  'Tombstone (1993)': [('Malice (1993)', 1.0)],
#  'Tomorrow Never Dies (1997)': [('Contact (1997)', 1.0)],
#  'Top Gun (1986)': [('Sound of Music, The (1965)', 1.0)],
#  'Toy Story (1995)': [('That Thing You Do! (1996)', 1.0),
#   ('Crash (1996)', 1.0),
#   ('Eraser (1996)', 1.0),
#   ('Family Thing, A (1996)', 1.0),
#   ('Contact (1997)', 1.0),
#   ('Game, The (1997)', 1.0),
#   ('Con Air (1997)', 1.0),
#   ('Frighteners, The (1996)', 1.0),
#   ('English Patient, The (1996)', 1.0)],
#  'Trainspotting (1996)': [('Killing Zoe (1994)', 1.0),
#   ('Life Less Ordinary, A (1997)', 1.0),
#   ('Aliens (1986)', 1.0),
#   ('Eat Drink Man Woman (1994)', 1.0),
#   ('Hate (Haine, La) (1995)', 1.0)],
#  'Trees Lounge (1996)': [('Star Wars (1977)', 1.0),
#   ('In the Name of the Father (1993)', 1.0)],
#  'Trial and Error (1997)': [('Girl 6 (1996)', 1.0)],
#  'Trigger Effect, The (1996)': [('Nightmare on Elm Street, A (1984)', 1.0)],
#  'True Lies (1994)': [('Tales from the Crypt Presents: Bordello of Blood (1996)',
#    1.0),
#   ("Dante's Peak (1997)", 1.0)],
#  'True Romance (1993)': [('Star Trek III: The Search for Spock (1984)', 1.0)],
#  'Truth About Cats & Dogs, The (1996)': [('Fan, The (1996)', 1.0),
#   ('E.T. the Extra-Terrestrial (1982)', 1.0),
#   ('Return of the Jedi (1983)', 1.0),
#   ('Heavenly Creatures (1994)', 1.0),
#   ('Independence Day (ID4) (1996)', 1.0),
#   ('French Kiss (1995)', 1.0),
#   ('Star Trek: First Contact (1996)', 1.0),
#   ('Birdcage, The (1996)', 1.0)],
#  'Twelve Monkeys (1995)': [('Sabrina (1954)', 1.0),
#   ('Full Monty, The (1997)', 1.0),
#   ('Fargo (1996)', 1.0),
#   ('Frighteners, The (1996)', 1.0),
#   ('Die xue shuang xiong (Killer, The) (1989)', 1.0)],
#  'Twister (1996)': [('Courage Under Fire (1996)', 1.0),
#   ('Silence of the Lambs, The (1991)', 1.0)],
#  'U Turn (1997)': [('Speed (1994)', 1.0), ('Cold Comfort Farm (1995)', 1.0)],
#  "Ulee's Gold (1997)": [('Star Wars (1977)', 1.0),
#   ("Devil's Own, The (1997)", 1.0)],
#  'Unbearable Lightness of Being, The (1988)': [('M*A*S*H (1970)', 1.0)],
#  'Up Close and Personal (1996)': [('Fifth Element, The (1997)', 1.0)],
#  'Vertigo (1958)': [('Eat Drink Man Woman (1994)', 1.0),
#   ('Mrs. Brown (Her Majesty, Mrs. Brown) (1997)', 1.0),
#   ('Sleeper (1973)', 1.0)],
#  'Very Brady Sequel, A (1996)': [('To Gillian on Her 37th Birthday (1996)',
#    1.0)],
#  'Village of the Damned (1995)': [('M (1931)', 1.0)],
#  'Volcano (1997)': [("Dante's Peak (1997)", 1.0),
#   ('Frighteners, The (1996)', 1.0),
#   ('Fly Away Home (1996)', 1.0),
#   ('English Patient, The (1996)', 1.0),
#   ('Evita (1996)', 1.0)],
#  'Wag the Dog (1997)': [('Edge, The (1997)', 1.0),
#   ('2001: A Space Odyssey (1968)', 1.0)],
#  'Waiting to Exhale (1995)': [('Indiana Jones and the Last Crusade (1989)',
#    1.0)],
#  'Wallace & Gromit: The Best of Aardman Animation (1996)': [('Contact (1997)',
#    1.0),
#   ('Adventures of Priscilla, Queen of the Desert, The (1994)', 1.0)],
#  'Waterworld (1995)': [('Santa Clause, The (1994)', 1.0),
#   ('Wizard of Oz, The (1939)', 1.0),
#   ('Saint, The (1997)', 1.0)],
#  'Welcome To Sarajevo (1997)': [('Cool Hand Luke (1967)', 1.0)],
#  "What's Eating Gilbert Grape (1993)": [('Alien (1979)', 1.0),
#   ('Kicked in the Head (1997)', 1.0)],
#  'When Harry Met Sally... (1989)': [('Being There (1979)', 1.0),
#   ('Boogie Nights (1997)', 1.0),
#   ('Jeffrey (1995)', 1.0),
#   ('Graduate, The (1967)', 1.0)],
#  'When the Cats Away (Chacun cherche son chat) (1996)': [('Beavis and Butt-head Do America (1996)',
#    1.0)],
#  'While You Were Sleeping (1995)': [('Streetcar Named Desire, A (1951)', 1.0),
#   ('Kids in the Hall: Brain Candy (1996)', 1.0)],
#  'White Squall (1996)': [('Philadelphia (1993)', 1.0)],
#  "William Shakespeare's Romeo and Juliet (1996)": [('Shawshank Redemption, The (1994)',
#    1.0)],
#  'Willy Wonka and the Chocolate Factory (1971)': [('Empire Strikes Back, The (1980)',
#    1.0),
#   ('Michael (1996)', 1.0),
#   ('Patton (1970)', 1.0)],
#  'Wings of Desire (1987)': [('Great Escape, The (1963)', 1.0)],
#  'Wings of the Dove, The (1997)': [('Afterglow (1997)', 1.0)],
#  'Wizard of Oz, The (1939)': [('Jackie Brown (1997)', 1.0),
#   ('Stalingrad (1993)', 1.0),
#   ('Beverly Hillbillies, The (1993)', 1.0)],
#  'Women, The (1939)': [('To Catch a Thief (1955)', 1.0)],
#  'Wrong Trousers, The (1993)': [('Jurassic Park (1993)', 1.0),
#   ('Mask, The (1994)', 1.0)],
#  'Young Frankenstein (1974)': [('Persuasion (1995)', 1.0)]}

# %%
def topNRecommendations(user_id,items_with_rating,item_sims,n):
    '''
    Calculate the top-N item recommendations for each user using the 
    weighted sums method
    '''
    # initialize dicts to store the score of each individual item,
    # since an item can exist in more than one item neighborhood
    totals = defaultdict(int)
    sim_sums = defaultdict(int)
    for (item,rating) in items_with_rating:
        # lookup the nearest neighbors for this item
        nearest_neighbors = item_sims.get(item,None)
        if nearest_neighbors:
            for (neighbor,(sim,count)) in nearest_neighbors:
                if neighbor != item:
                    # update totals and sim_sums with the rating data
                    totals[neighbor] += sim * rating
                    sim_sums[neighbor] += sim
    # create the normalized list of scored items 
    scored_items = [(total/sim_sums[item],item) for item,total in totals.items()]
    # sort the scored items in ascending order
    scored_items.sort(reverse=True)
    # take out the item score
    # ranked_items = [x[1] for x in scored_items]
    return user_id,scored_items[:n]

# %%
'''
Calculate the top-N item recommendations for each user
    user_id -> [item1,item2,item3,...]
'''
user_item_recs = user_item_pairs.map(
        lambda p: topNRecommendations(p[0],p[1],isb.value,500))
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-309-66bc8a631887> in <module>()
#       4 '''
#       5 user_item_recs = user_item_pairs.map(
# ----> 6         lambda p: topNRecommendations(p[0],p[1],isb.value,500)).collect()
#
# /home/hadoop/app/spark-2.4.3-hadoop2.7/python/pyspark/rdd.py in collect(self)
#     814         """
#     815         with SCCallSiteSync(self.context) as css:
# --> 816             sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     817         return list(_load_from_socket(sock_info, self._jrdd_deserializer))
#     818
#
# /home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /home/hadoop/app/spark-2.4.3-hadoop2.7/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.collectAndServe.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 464.0 failed 1 times, most recent failure: Lost task 0.0 in stage 464.0 (TID 269, localhost, executor driver): org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/pyspark.zip/pyspark/worker.py", line 377, in main
#     process()
#   File "/home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/pyspark.zip/pyspark/worker.py", line 372, in process
#     serializer.dump_stream(func(split_index, iterator), outfile)
#   File "/home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/pyspark.zip/pyspark/serializers.py", line 393, in dump_stream
#     vs = list(itertools.islice(iterator, batch))
#   File "/home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/pyspark.zip/pyspark/util.py", line 99, in wrapper
#     return f(*args, **kwargs)
#   File "<ipython-input-309-66bc8a631887>", line 6, in <lambda>
#   File "<ipython-input-308-711d82f90be2>", line 14, in topNRecommendations
# TypeError: 'float' object is not iterable
#
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.handlePythonException(PythonRunner.scala:452)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRunner.scala:588)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRunner.scala:571)
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.hasNext(PythonRunner.scala:406)
# 	at org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)
# 	at scala.collection.Iterator$class.foreach(Iterator.scala:891)
# 	at org.apache.spark.InterruptibleIterator.foreach(InterruptibleIterator.scala:28)
# 	at scala.collection.generic.Growable$class.$plus$plus$eq(Growable.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.$plus$plus$eq(ArrayBuffer.scala:104)
# 	at scala.collection.mutable.ArrayBuffer.$plus$plus$eq(ArrayBuffer.scala:48)
# 	at scala.collection.TraversableOnce$class.to(TraversableOnce.scala:310)
# 	at org.apache.spark.InterruptibleIterator.to(InterruptibleIterator.scala:28)
# 	at scala.collection.TraversableOnce$class.toBuffer(TraversableOnce.scala:302)
# 	at org.apache.spark.InterruptibleIterator.toBuffer(InterruptibleIterator.scala:28)
# 	at scala.collection.TraversableOnce$class.toArray(TraversableOnce.scala:289)
# 	at org.apache.spark.InterruptibleIterator.toArray(InterruptibleIterator.scala:28)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1$$anonfun$13.apply(RDD.scala:945)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1$$anonfun$13.apply(RDD.scala:945)
# 	at org.apache.spark.SparkContext$$anonfun$runJob$5.apply(SparkContext.scala:2101)
# 	at org.apache.spark.SparkContext$$anonfun$runJob$5.apply(SparkContext.scala:2101)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:90)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:121)
# 	at org.apache.spark.executor.Executor$TaskRunner$$anonfun$10.apply(Executor.scala:408)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1360)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:414)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617)
# 	at java.lang.Thread.run(Thread.java:745)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1889)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1877)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1876)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1876)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:926)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:926)
# 	at scala.Option.foreach(Option.scala:257)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:926)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:2110)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2059)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2048)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:737)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2061)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2082)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2101)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2126)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:945)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:363)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:944)
# 	at org.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:166)
# 	at org.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala)
# 	at sun.reflect.GeneratedMethodAccessor84.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/pyspark.zip/pyspark/worker.py", line 377, in main
#     process()
#   File "/home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/pyspark.zip/pyspark/worker.py", line 372, in process
#     serializer.dump_stream(func(split_index, iterator), outfile)
#   File "/home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/pyspark.zip/pyspark/serializers.py", line 393, in dump_stream
#     vs = list(itertools.islice(iterator, batch))
#   File "/home/hadoop/app/spark-2.4.3-hadoop2.7/python/lib/pyspark.zip/pyspark/util.py", line 99, in wrapper
#     return f(*args, **kwargs)
#   File "<ipython-input-309-66bc8a631887>", line 6, in <lambda>
#   File "<ipython-input-308-711d82f90be2>", line 14, in topNRecommendations
# TypeError: 'float' object is not iterable
#
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.handlePythonException(PythonRunner.scala:452)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRunner.scala:588)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRunner.scala:571)
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.hasNext(PythonRunner.scala:406)
# 	at org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)
# 	at scala.collection.Iterator$class.foreach(Iterator.scala:891)
# 	at org.apache.spark.InterruptibleIterator.foreach(InterruptibleIterator.scala:28)
# 	at scala.collection.generic.Growable$class.$plus$plus$eq(Growable.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.$plus$plus$eq(ArrayBuffer.scala:104)
# 	at scala.collection.mutable.ArrayBuffer.$plus$plus$eq(ArrayBuffer.scala:48)
# 	at scala.collection.TraversableOnce$class.to(TraversableOnce.scala:310)
# 	at org.apache.spark.InterruptibleIterator.to(InterruptibleIterator.scala:28)
# 	at scala.collection.TraversableOnce$class.toBuffer(TraversableOnce.scala:302)
# 	at org.apache.spark.InterruptibleIterator.toBuffer(InterruptibleIterator.scala:28)
# 	at scala.collection.TraversableOnce$class.toArray(TraversableOnce.scala:289)
# 	at org.apache.spark.InterruptibleIterator.toArray(InterruptibleIterator.scala:28)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1$$anonfun$13.apply(RDD.scala:945)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1$$anonfun$13.apply(RDD.scala:945)
# 	at org.apache.spark.SparkContext$$anonfun$runJob$5.apply(SparkContext.scala:2101)
# 	at org.apache.spark.SparkContext$$anonfun$runJob$5.apply(SparkContext.scala:2101)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:90)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:121)
# 	at org.apache.spark.executor.Executor$TaskRunner$$anonfun$10.apply(Executor.scala:408)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1360)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:414)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617)
# 	... 1 more

# %% [markdown]
# # 测试结果准确性

# %%
'''
Read in test data and calculate MAE
'''
test_ratings = defaultdict(list)
# read in the test data
f = open("/home/hadoop/workspaces/spark_knn_recommender/ratings1.txt", 'rt')
reader = csv.reader(f, delimiter='|')
for row in reader:
    user = row[0]
    item = row[1]
    rating = row[2]
    test_ratings[user] += [(item,rating)]

# %%
# create train-test rating tuples
preds = []
for (user,items_with_rating) in user_item_recs:
    for (rating,item) in items_with_rating:
        for (test_item,test_rating) in test_ratings[user]:                
            if str(test_item) == str(item):
                preds.append((rating,float(test_rating)))

mae = MAE(preds)
result = mae.compute()
print "Mean Absolute Error: ",result
# Out:
#   File "<ipython-input-313-a276afcca426>", line 11
#     print "Mean Absolute Error: ",result
#                                 ^
# SyntaxError: Missing parentheses in call to 'print'
